# %%
import pandas as pd
import numpy as np
import talib as ta
import os 
from alphien.utils import get_all_data, _read_output
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
def add_features(data):
    """Add features to raw data

    Parameters
    ----------
    data: pd.DataFrame
        Raw data

    Returns
    -------
    pd.DataFrame
        Results
    
    NOTE: MACD and SMA are adjusted to cum. corp. actions effect
    
    """
    data = data.copy()
    data['date'] = pd.to_datetime(data['date'])
    data = data.set_index('date')
    data['tradevol'] = (data['volume']) * ((data['high'] + data['low'])/2)
    data['spread'] = data['high'] - data['low']
    data['returns'] = data['adjClose'].pct_change(1)
    data['vol'] = data['returns'].rolling(126).std()
    


    data['MOM5'] = data['adjClose'].pct_change(5)
    data['MOM22'] = data['adjClose'].pct_change(22)
    data['MOM252'] = data['adjClose'].pct_change(252)

    data['MACD'], data['MACDSignal'], data['MACDHist'] = ta.MACD(data['adjClose'], 12, 26, 9)
    #Scaling
    data['MACD'] = data['MACD']/data['adjClose']
    data['MACDSignal'] = data['MACDHist']/data['adjClose']
    data['MACDSignal'] = data['MACDHist']/data['adjClose']

    data['RSI14'] = ta.RSI(data['adjClose'], 14)
    data['RSI28'] = ta.RSI(data['adjClose'], 28)
    data['RSI56'] = ta.RSI(data['adjClose'], 56)

    data['ADX14'] = ta.ADX(data['adjHigh'], data['adjLow'], data['adjClose'], 14)
    data['ADX56'] = ta.ADX(data['adjHigh'], data['adjLow'], data['adjClose'], 56)

    data['SMA14'] = ta.SMA(data['adjClose'], 14)/data['adjClose']
    data['SMA42'] = ta.SMA(data['adjClose'], 42)/data['adjClose']



    for lag in [3,4,14,56,112,224]:
        col = 'C' + str(lag)
        data[col] = data['close'].shift(lag)




    data = data.drop(['adjHigh', 'adjLow', 'adjOpen', 'adjClose','adjVolume','divCash','splitFactor'], axis = 1)


    # data['Forward Return Daily'] = data['adjClose'].shift(-1)/data['adjClose']
    # data['Forward Return Quarterly'] = data['adjClose'].shift(-63)/data['adjClose']
    data = data.replace(np.inf,np.nan)
    data = data.dropna()
    return data

def rebase(arr, idx = -1):
    return arr/arr[idx]

# %%
datalist = list(_read_output().values())
datalist = [data for data in datalist if data.shape[0] > 1]
datalist = [add_features(data) for data in datalist]

# %%
labels = pd.read_csv(os.path.join(os.getcwd(), "labels60.csv")).drop(["Unnamed: 0"], axis = 1)
labels['target'] = 1

# %%
df = pd.concat(datalist)
df = df.reset_index()
df = df.sort_values(by=['date','ticker'])
# df = df.set_index(['date','ticker'])
df = df.set_index('date')
df = df['2000-01-01':'2020-07-17']
df = df.reset_index()
df["date"] = df["date"].astype(str)

# %%
df = df.merge(labels, left_on= ["date", "ticker"], right_on= ["date", "ticker"], how="left")
df = df.fillna(0)

#drop ticker
df = df.drop('ticker', axis = 1)
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

#drop dates
df_train = df['2009-01-01':'2016-01-01'].reset_index(drop = True)
df_past = df['2000-01-01':'2009-01-01'].reset_index(drop=True)
df_future = df['2016-01-01':'2020-07-07'].reset_index(drop=True)

#LB test
trading_days = df.index.unique()
dfq = pd.DataFrame(index = trading_days)
dfq['trading_days'] = trading_days
dfq = dfq.resample('Q').bfill()
lb_idx = pd.to_datetime(dfq['trading_days'].values[:-1])
lb_idx = lb_idx.tz_localize('UTC')
df_lb = df.loc[lb_idx].copy().reset_index(drop=True)

# %%
Y_train = df_train['target']
X_train = df_train.drop("target", axis = 1)

Y_past = df_past['target']
X_past = df_past.drop("target", axis = 1)

Y_future = df_future['target']
X_future = df_future.drop("target", axis = 1)

Y_lb = df_lb['target']
X_lb = df_lb.drop("target", axis = 1)

# %%
df
# Out:
#                             close    high     low    open    volume  \
# date
# 2000-01-03 00:00:00+00:00  111.94  112.50  101.69  104.87   4783900
# 2000-01-03 00:00:00+00:00   15.56   15.75   15.25   15.50    696200
# 2000-01-03 00:00:00+00:00   36.50   37.31   36.50   37.03     92800
# 2000-01-03 00:00:00+00:00   35.00   36.00   34.75   35.25  10635000
# 2000-01-03 00:00:00+00:00   17.69   17.75   17.50   17.56   1509900
# ...                           ...     ...     ...     ...       ...
# 2020-07-17 00:00:00+00:00   90.57   91.00   89.43   90.05   1293900
# 2020-07-17 00:00:00+00:00  135.14  136.00  130.88  131.11   1639386
# 2020-07-17 00:00:00+00:00  273.10  274.54  269.10  269.10    258700
# 2020-07-17 00:00:00+00:00   32.56   33.65   32.46   33.24   2325300
# 2020-07-17 00:00:00+00:00  144.66  145.28  142.23  143.80   1518100
#
#                                tradevol  spread   returns       vol      MOM5  \
# date
# 2000-01-03 00:00:00+00:00  5.123318e+08   10.81  0.088805  0.038954  0.127178
# 2000-01-03 00:00:00+00:00  1.079110e+07    0.50  0.024358  0.043181  0.121037
# 2000-01-03 00:00:00+00:00  3.424784e+06    0.81 -0.006803  0.052138 -0.058065
# 2000-01-03 00:00:00+00:00  3.762131e+08    1.25 -0.036078  0.024361 -0.058887
# 2000-01-03 00:00:00+00:00  2.661199e+07    0.25  0.000000  0.034218 -0.024269
# ...                                 ...     ...       ...       ...       ...
# 2020-07-17 00:00:00+00:00  1.167292e+08    1.57  0.009812  0.037177  0.038171
# 2020-07-17 00:00:00+00:00  2.187597e+08    5.12  0.035080  0.040159  0.131541
# 2020-07-17 00:00:00+00:00  7.031983e+07    5.44  0.020324  0.039169  0.047685
# 2020-07-17 00:00:00+00:00  7.686279e+07    1.19 -0.024858  0.040882  0.010866
# 2020-07-17 00:00:00+00:00  2.182345e+08    3.05  0.012033  0.032145  0.056619
#
#                               MOM22    MOM252      MACD  MACDSignal  MACDHist  \
# date
# 2000-01-03 00:00:00+00:00  0.086163  1.713697  0.020690    0.000472  0.000407
# 2000-01-03 00:00:00+00:00  0.250804 -0.565485  0.032433    0.024622  0.076232
# 2000-01-03 00:00:00+00:00  0.186992  3.112676  0.039850   -0.049115 -0.896340
# 2000-01-03 00:00:00+00:00 -0.065171 -0.277261 -0.008137   -0.001585 -0.014502
# 2000-01-03 00:00:00+00:00 -0.006738 -0.081008 -0.003291    0.000168  0.002326
# ...                             ...       ...       ...         ...       ...
# 2020-07-17 00:00:00+00:00 -0.014043 -0.184760  0.001739    0.004442  0.400340
# 2020-07-17 00:00:00+00:00  0.033275  0.097705  0.011435    0.013242  1.786272
# 2020-07-17 00:00:00+00:00  0.024919  0.494882  0.013850    0.004320  1.179883
# 2020-07-17 00:00:00+00:00 -0.119286 -0.260190 -0.011230   -0.000161 -0.005185
# 2020-07-17 00:00:00+00:00  0.063288  0.265761  0.013925    0.004572  0.661449
#
#                                RSI14      RSI28      RSI56      ADX14  \
# date
# 2000-01-03 00:00:00+00:00  64.527080  62.013552  61.015343  23.559854
# 2000-01-03 00:00:00+00:00  67.775363  53.111243  45.256718  31.731481
# 2000-01-03 00:00:00+00:00  47.207328  54.832295  58.254673  50.202857
# 2000-01-03 00:00:00+00:00  40.787791  43.629951  44.672127  17.448432
# 2000-01-03 00:00:00+00:00  46.279919  47.261755  48.272910   9.159197
# ...                              ...        ...        ...        ...
# 2020-07-17 00:00:00+00:00  58.795319  54.284024  51.200794  14.461969
# 2020-07-17 00:00:00+00:00  66.511949  58.203801  53.537474  15.979496
# 2020-07-17 00:00:00+00:00  61.186521  57.949549  55.504660  15.891036
# 2020-07-17 00:00:00+00:00  47.700685  48.928800  48.193604  12.010633
# 2020-07-17 00:00:00+00:00  67.533199  59.446929  55.332528  16.048115
#
#                                ADX56     SMA14     SMA42      C3      C4  \
# date
# 2000-01-03 00:00:00+00:00  25.205360  0.898038  0.876111  100.69   98.19
# 2000-01-03 00:00:00+00:00  24.477765  0.886293  0.837679   14.69   15.13
# 2000-01-03 00:00:00+00:00  28.568606  1.176262  0.935127   36.00   35.50
# 2000-01-03 00:00:00+00:00  10.207186  1.048122  1.057388   36.38   37.06
# 2000-01-03 00:00:00+00:00   4.607502  1.013567  1.011282   18.19   18.45
# ...                              ...       ...       ...     ...     ...
# 2020-07-17 00:00:00+00:00   8.274992  0.968990  0.987778   88.18   87.43
# 2020-07-17 00:00:00+00:00  10.423259  0.903682  0.925371  124.17  120.87
# 2020-07-17 00:00:00+00:00  11.875150  0.952278  0.949440  266.47  255.50
# 2020-07-17 00:00:00+00:00  13.522322  0.998508  1.043451   32.02   32.88
# 2020-07-17 00:00:00+00:00   8.032365  0.958610  0.947256  140.40  138.31
#
#                               C14     C56    C112     C224  target
# date
# 2000-01-03 00:00:00+00:00   99.00   64.03   50.94   37.690     0.0
# 2000-01-03 00:00:00+00:00   12.44   18.00   25.37   75.120     0.0
# 2000-01-03 00:00:00+00:00   45.75   17.00   15.88    9.375     0.0
# 2000-01-03 00:00:00+00:00   33.93   38.69   43.13   45.000     0.0
# 2000-01-03 00:00:00+00:00   17.75   21.75   17.81   19.630     0.0
# ...                           ...     ...     ...      ...     ...
# 2020-07-17 00:00:00+00:00   84.79   88.27  103.74  116.970     0.0
# 2020-07-17 00:00:00+00:00  115.43  114.74  159.01  134.500     0.0
# 2020-07-17 00:00:00+00:00  246.42  228.48  252.09  198.590     0.0
# 2020-07-17 00:00:00+00:00   32.29   31.33   47.01   39.490     0.0
# 2020-07-17 00:00:00+00:00  132.66  123.00  138.97  125.240     0.0
#
# [3234820 rows x 29 columns]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import HistGradientBoostingClassifier

param_grid = {"learning_rate": [0.01, 0.001, 0.03]}

model = HistGradientBoostingClassifier(max_iter=1000, learning_rate= 0.01, validation_fraction=0.4, early_stopping=True, verbose=0)
model = hg.fit(X_train, Y_train)

Y_train_pred = model.predict(X_train)
Y_past_pred = model.predict(X_past)
Y_future_pred = model.predict(X_future)
Y_lb_pred = model.predict(X_lb)

train_score = roc_auc_score(Y_train, Y_train_pred)
past_score = roc_auc_score(Y_past, Y_past_pred)
future_score = roc_auc_score(Y_future, Y_future_pred)
lb_score = roc_auc_score(Y_lb, Y_lb_pred)

print(train_score, past_score, future_score, lb_score)
# Out:
# n loss: 0.25771, val loss: 0.26046, in 0.101s
# [795/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25770, val loss: 0.26045, in 0.105s
# [796/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25768, val loss: 0.26043, in 0.110s
# [797/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25766, val loss: 0.26041, in 0.089s
# [798/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25764, val loss: 0.26040, in 0.096s
# [799/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25763, val loss: 0.26039, in 0.092s
# [800/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25762, val loss: 0.26038, in 0.100s
# [801/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25760, val loss: 0.26037, in 0.105s
# [802/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25758, val loss: 0.26035, in 0.097s
# [803/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25756, val loss: 0.26034, in 0.108s
# [804/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25755, val loss: 0.26033, in 0.104s
# [805/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25754, val loss: 0.26033, in 0.087s
# [806/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25753, val loss: 0.26032, in 0.094s
# [807/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25752, val loss: 0.26031, in 0.088s
# [808/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25750, val loss: 0.26030, in 0.102s
# [809/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25749, val loss: 0.26029, in 0.109s
# [810/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25748, val loss: 0.26028, in 0.103s
# [811/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25746, val loss: 0.26027, in 0.139s
# [812/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25745, val loss: 0.26026, in 0.086s
# [813/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25744, val loss: 0.26025, in 0.090s
# [814/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25743, val loss: 0.26024, in 0.098s
# [815/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25741, val loss: 0.26023, in 0.096s
# [816/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25739, val loss: 0.26022, in 0.101s
# [817/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25738, val loss: 0.26020, in 0.093s
# [818/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25736, val loss: 0.26019, in 0.100s
# [819/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25735, val loss: 0.26018, in 0.097s
# [820/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25734, val loss: 0.26017, in 0.094s
# [821/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25732, val loss: 0.26016, in 0.104s
# [822/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25730, val loss: 0.26014, in 0.093s
# [823/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25728, val loss: 0.26013, in 0.095s
# [824/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25726, val loss: 0.26011, in 0.095s
# [825/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25725, val loss: 0.26011, in 0.106s
# [826/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25724, val loss: 0.26010, in 0.109s
# [827/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25723, val loss: 0.26009, in 0.094s
# [828/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25721, val loss: 0.26008, in 0.094s
# [829/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25721, val loss: 0.26007, in 0.092s
# [830/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25719, val loss: 0.26006, in 0.100s
# [831/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25718, val loss: 0.26005, in 0.105s
# [832/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25716, val loss: 0.26004, in 0.096s
# [833/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25715, val loss: 0.26003, in 0.092s
# [834/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25713, val loss: 0.26001, in 0.103s
# [835/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25712, val loss: 0.26000, in 0.093s
# [836/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25710, val loss: 0.25999, in 0.106s
# [837/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25709, val loss: 0.25997, in 0.106s
# [838/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25707, val loss: 0.25996, in 0.099s
# [839/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25705, val loss: 0.25995, in 0.097s
# [840/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25704, val loss: 0.25994, in 0.102s
# [841/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25703, val loss: 0.25993, in 0.097s
# [842/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25702, val loss: 0.25993, in 0.092s
# [843/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25701, val loss: 0.25992, in 0.091s
# [844/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25700, val loss: 0.25991, in 0.089s
# [845/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25699, val loss: 0.25990, in 0.085s
# [846/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25697, val loss: 0.25989, in 0.101s
# [847/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25696, val loss: 0.25988, in 0.090s
# [848/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25694, val loss: 0.25986, in 0.101s
# [849/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25693, val loss: 0.25986, in 0.089s
# [850/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25692, val loss: 0.25985, in 0.111s
# [851/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25690, val loss: 0.25984, in 0.099s
# [852/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25688, val loss: 0.25982, in 0.092s
# [853/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25687, val loss: 0.25981, in 0.094s
# [854/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25685, val loss: 0.25980, in 0.099s
# [855/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25684, val loss: 0.25979, in 0.096s
# [856/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25683, val loss: 0.25978, in 0.101s
# [857/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25681, val loss: 0.25976, in 0.087s
# [858/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25680, val loss: 0.25976, in 0.097s
# [859/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25678, val loss: 0.25974, in 0.105s
# [860/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25678, val loss: 0.25974, in 0.094s
# [861/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25676, val loss: 0.25973, in 0.096s
# [862/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25674, val loss: 0.25971, in 0.094s
# [863/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25673, val loss: 0.25970, in 0.092s
# [864/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25671, val loss: 0.25968, in 0.149s
# [865/1000] 1 tree, 31 leaves, max depth = 8, train loss: 0.25670, val loss: 0.25967, in 0.094s
# [866/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25668, val loss: 0.25966, in 0.091s
# [867/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25667, val loss: 0.25965, in 0.091s
# [868/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25665, val loss: 0.25964, in 0.103s
# [869/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25664, val loss: 0.25963, in 0.098s
# [870/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25663, val loss: 0.25963, in 0.092s
# [871/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25663, val loss: 0.25962, in 0.093s
# [872/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25661, val loss: 0.25961, in 0.091s
# [873/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25660, val loss: 0.25960, in 0.093s
# [874/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25657, val loss: 0.25958, in 0.102s
# [875/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25655, val loss: 0.25956, in 0.102s
# [876/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25654, val loss: 0.25956, in 0.092s
# [877/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25653, val loss: 0.25955, in 0.099s
# [878/1000] 1 tree, 31 leaves, max depth = 16, train loss: 0.25651, val loss: 0.25954, in 0.114s
# [879/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25650, val loss: 0.25952, in 0.092s
# [880/1000] 1 tree, 31 leaves, max depth = 18, train loss: 0.25648, val loss: 0.25951, in 0.096s
# [881/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25647, val loss: 0.25950, in 0.097s
# [882/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25645, val loss: 0.25949, in 0.102s
# [883/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25643, val loss: 0.25948, in 0.091s
# [884/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25642, val loss: 0.25947, in 0.095s
# [885/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25640, val loss: 0.25945, in 0.097s
# [886/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25639, val loss: 0.25944, in 0.101s
# [887/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25638, val loss: 0.25944, in 0.093s
# [888/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25636, val loss: 0.25942, in 0.098s
# [889/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25635, val loss: 0.25942, in 0.092s
# [890/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25634, val loss: 0.25941, in 0.101s
# [891/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25632, val loss: 0.25939, in 0.091s
# [892/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25631, val loss: 0.25938, in 0.109s
# [893/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25630, val loss: 0.25937, in 0.094s
# [894/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25628, val loss: 0.25936, in 0.094s
# [895/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25626, val loss: 0.25934, in 0.110s
# [896/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25625, val loss: 0.25933, in 0.097s
# [897/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25624, val loss: 0.25933, in 0.093s
# [898/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25623, val loss: 0.25932, in 0.107s
# [899/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25621, val loss: 0.25931, in 0.097s
# [900/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25620, val loss: 0.25930, in 0.094s
# [901/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25620, val loss: 0.25930, in 0.093s
# [902/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25618, val loss: 0.25928, in 0.106s
# [903/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25616, val loss: 0.25926, in 0.106s
# [904/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25615, val loss: 0.25926, in 0.101s
# [905/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25613, val loss: 0.25924, in 0.108s
# [906/1000] 1 tree, 31 leaves, max depth = 17, train loss: 0.25611, val loss: 0.25923, in 0.106s
# [907/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25610, val loss: 0.25922, in 0.110s
# [908/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25608, val loss: 0.25921, in 0.110s
# [909/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25607, val loss: 0.25919, in 0.101s
# [910/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25605, val loss: 0.25918, in 0.098s
# [911/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25604, val loss: 0.25917, in 0.100s
# [912/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25603, val loss: 0.25916, in 0.100s
# [913/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25602, val loss: 0.25916, in 0.098s
# [914/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25601, val loss: 0.25914, in 0.105s
# [915/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25599, val loss: 0.25913, in 0.097s
# [916/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25599, val loss: 0.25913, in 0.096s
# [917/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25597, val loss: 0.25911, in 0.100s
# [918/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25596, val loss: 0.25911, in 0.101s
# [919/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25593, val loss: 0.25908, in 0.109s
# [920/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25592, val loss: 0.25908, in 0.086s
# [921/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25591, val loss: 0.25906, in 0.095s
# [922/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25589, val loss: 0.25905, in 0.126s
# [923/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25588, val loss: 0.25904, in 0.093s
# [924/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25586, val loss: 0.25903, in 0.094s
# [925/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25585, val loss: 0.25902, in 0.106s
# [926/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25584, val loss: 0.25901, in 0.091s
# [927/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25583, val loss: 0.25900, in 0.091s
# [928/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25582, val loss: 0.25899, in 0.096s
# [929/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25580, val loss: 0.25898, in 0.127s
# [930/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25579, val loss: 0.25897, in 0.096s
# [931/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25577, val loss: 0.25896, in 0.100s
# [932/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25575, val loss: 0.25894, in 0.108s
# [933/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25573, val loss: 0.25893, in 0.097s
# [934/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25572, val loss: 0.25893, in 0.096s
# [935/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25571, val loss: 0.25891, in 0.093s
# [936/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25569, val loss: 0.25890, in 0.095s
# [937/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25569, val loss: 0.25890, in 0.093s
# [938/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25567, val loss: 0.25889, in 0.096s
# [939/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25565, val loss: 0.25887, in 0.104s
# [940/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25564, val loss: 0.25886, in 0.104s
# [941/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25562, val loss: 0.25885, in 0.101s
# [942/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25562, val loss: 0.25884, in 0.089s
# [943/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25560, val loss: 0.25883, in 0.093s
# [944/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25559, val loss: 0.25882, in 0.090s
# [945/1000] 1 tree, 31 leaves, max depth = 16, train loss: 0.25556, val loss: 0.25880, in 0.110s
# [946/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25555, val loss: 0.25879, in 0.102s
# [947/1000] 1 tree, 31 leaves, max depth = 18, train loss: 0.25553, val loss: 0.25878, in 0.094s
# [948/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25552, val loss: 0.25877, in 0.087s
# [949/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25551, val loss: 0.25876, in 0.088s
# [950/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25549, val loss: 0.25875, in 0.099s
# [951/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25548, val loss: 0.25874, in 0.105s
# [952/1000] 1 tree, 31 leaves, max depth = 8, train loss: 0.25546, val loss: 0.25873, in 0.091s
# [953/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25545, val loss: 0.25872, in 0.095s
# [954/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25544, val loss: 0.25871, in 0.098s
# [955/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25542, val loss: 0.25870, in 0.100s
# [956/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25540, val loss: 0.25868, in 0.109s
# [957/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25539, val loss: 0.25868, in 0.095s
# [958/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25538, val loss: 0.25867, in 0.098s
# [959/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25536, val loss: 0.25866, in 0.094s
# [960/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25535, val loss: 0.25865, in 0.096s
# [961/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25533, val loss: 0.25863, in 0.120s
# [962/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25531, val loss: 0.25862, in 0.099s
# [963/1000] 1 tree, 31 leaves, max depth = 16, train loss: 0.25529, val loss: 0.25860, in 0.106s
# [964/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25529, val loss: 0.25860, in 0.087s
# [965/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25528, val loss: 0.25860, in 0.089s
# [966/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25526, val loss: 0.25858, in 0.094s
# [967/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25525, val loss: 0.25857, in 0.107s
# [968/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25523, val loss: 0.25856, in 0.120s
# [969/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25523, val loss: 0.25856, in 0.088s
# [970/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25522, val loss: 0.25855, in 0.088s
# [971/1000] 1 tree, 31 leaves, max depth = 16, train loss: 0.25521, val loss: 0.25855, in 0.087s
# [972/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25520, val loss: 0.25854, in 0.097s
# [973/1000] 1 tree, 31 leaves, max depth = 8, train loss: 0.25519, val loss: 0.25853, in 0.090s
# [974/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25517, val loss: 0.25852, in 0.092s
# [975/1000] 1 tree, 31 leaves, max depth = 16, train loss: 0.25516, val loss: 0.25851, in 0.103s
# [976/1000] 1 tree, 31 leaves, max depth = 8, train loss: 0.25514, val loss: 0.25850, in 0.095s
# [977/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25513, val loss: 0.25849, in 0.105s
# [978/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25511, val loss: 0.25847, in 0.097s
# [979/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25510, val loss: 0.25847, in 0.128s
# [980/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25509, val loss: 0.25846, in 0.098s
# [981/1000] 1 tree, 31 leaves, max depth = 18, train loss: 0.25507, val loss: 0.25844, in 0.104s
# [982/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25505, val loss: 0.25843, in 0.103s
# [983/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25504, val loss: 0.25842, in 0.092s
# [984/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25502, val loss: 0.25841, in 0.099s
# [985/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25501, val loss: 0.25841, in 0.092s
# [986/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25500, val loss: 0.25839, in 0.096s
# [987/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25498, val loss: 0.25838, in 0.098s
# [988/1000] 1 tree, 31 leaves, max depth = 15, train loss: 0.25497, val loss: 0.25837, in 0.095s
# [989/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25496, val loss: 0.25836, in 0.092s
# [990/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25495, val loss: 0.25836, in 0.092s
# [991/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25494, val loss: 0.25835, in 0.092s
# [992/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25493, val loss: 0.25834, in 0.093s
# [993/1000] 1 tree, 31 leaves, max depth = 9, train loss: 0.25491, val loss: 0.25833, in 0.107s
# [994/1000] 1 tree, 31 leaves, max depth = 10, train loss: 0.25490, val loss: 0.25832, in 0.092s
# [995/1000] 1 tree, 31 leaves, max depth = 12, train loss: 0.25489, val loss: 0.25832, in 0.097s
# [996/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25488, val loss: 0.25830, in 0.111s
# [997/1000] 1 tree, 31 leaves, max depth = 13, train loss: 0.25486, val loss: 0.25829, in 0.095s
# [998/1000] 1 tree, 31 leaves, max depth = 16, train loss: 0.25485, val loss: 0.25828, in 0.090s
# [999/1000] 1 tree, 31 leaves, max depth = 14, train loss: 0.25484, val loss: 0.25827, in 0.106s
# [1000/1000] 1 tree, 31 leaves, max depth = 11, train loss: 0.25483, val loss: 0.25827, in 0.098s
# Fit 1000 trees in 108.576 s, (31000 total leaves)
# Time spent computing histograms: 18.736s
# Time spent finding best splits:  1.522s
# Time spent applying splits:      5.424s
# Time spent predicting:           1.113s

# %%
from sklearn.ensemble import RandomForestClassifier


# params_grid = {'n_estimators': [50, 100, 200]}
# model_gs = GridSearchCV(rf, params_grid, cv=5)
# model_gs.fit(X_train, y_train)

params_rf = {'n_estimators': 200}
model = RandomForestClassifier(**params_rf)
model = rf.fit(X_train, Y_train)
model.fit(X_train, Y_train)

Y_train_pred = model.predict(X_train)
Y_past_pred = model.predict(X_past)
Y_future_pred = model.predict(X_future)
Y_lb_pred = model.predict(X_lb)

train_score = roc_auc_score(Y_train, Y_train_pred)
past_score = roc_auc_score(Y_past, Y_past_pred)
future_score = roc_auc_score(Y_future, Y_future_pred)
lb_score = roc_auc_score(Y_lb, Y_lb_pred)

print(train_score, past_score, future_score, lb_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-076cce9ba4f5> in <module>
#       4
#       5 rf = RandomForestClassifier(**params_rf)
# ----> 6 rf_trained = rf.fit(X_train, Y_train)
#       7
#       8 rf.fit(X_train, Y_train)
#
# c:\Users\Leonardus\repos\UBSQHackathon\venv\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     346
#     347         # Check parameters
# --> 348         self._validate_estimator()
#     349
#     350         if not self.bootstrap and self.oob_score:
#
# c:\Users\Leonardus\repos\UBSQHackathon\venv\lib\site-packages\sklearn\ensemble\_base.py in _validate_estimator(self, default)
#     128         """
#     129         if not isinstance(self.n_estimators, numbers.Integral):
# --> 130             raise ValueError("n_estimators must be an integer, "
#     131                              "got {0}.".format(type(self.n_estimators)))
#     132
#
# ValueError: n_estimators must be an integer, got <class 'list'>.

# %%
# Out:
# 0.5229484892415796 0.5067157296734613 0.5038306067071535 0.5139969823941288
